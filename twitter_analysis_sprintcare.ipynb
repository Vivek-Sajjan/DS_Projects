# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek-Sajjan/DS_Projects/blob/main/twitter_analysis_sprintcare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Sprintcare dataset-csv.csv')
display(df.head())
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %%
df.shape
# Out:
# (11701, 7)

# %%
# Create a new 'role' column based on the 'inbound' column
df['role'] = df['inbound'].apply(lambda x: 'Customer' if x else 'Service Provider')

# Get the list of existing columns
cols = df.columns.tolist()

# Move the 'role' column to the second position (index 2)
cols.insert(2, cols.pop(cols.index('role')))

# Reindex the DataFrame with the new column order
df = df[cols]

# Display the head of the modified DataFrame
display(df.head())
# Out:
#    tweet_id   author_id              role  inbound  \
# 0         1  sprintcare  Service Provider    False
# 1         2      115712          Customer     True
# 2         3      115712          Customer     True
# 3         4  sprintcare  Service Provider    False
# 4         5      115712          Customer     True
#
#                        created_at  \
# 0  Tue Oct 31 22:10:47 +0000 2017
# 1  Tue Oct 31 22:11:45 +0000 2017
# 2  Tue Oct 31 22:08:27 +0000 2017
# 3  Tue Oct 31 21:54:49 +0000 2017
# 4  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %% [markdown]
# # Task
# Analyze the "Sprintcare dataset-csv.csv" file and build the first 20 conversations.

# %% [markdown]
# ## Identify conversation starters
#
# ### Subtask:
# Find the initial tweets that start a conversation (those with no `in_response_to_tweet_id`).

# %% [markdown]
# **Reasoning**:
# Filter the dataframe to find tweets with no response, which signify the start of a conversation. Store the results in a new dataframe and display the head.

# %%
conversation_starters_df = df[df['in_response_to_tweet_id'].isnull()]
display(conversation_starters_df.head())
# Out:
#     tweet_id author_id      role  inbound                      created_at  \
# 6          8    115712  Customer     True  Tue Oct 31 21:45:10 +0000 2017
# 22      1293    115712  Customer     True  Tue Oct 31 22:24:51 +0000 2017
# 39      3178    116445  Customer     True  Tue Oct 31 22:55:37 +0000 2017
# 52      5523    117001  Customer     True  Tue Oct 31 23:12:51 +0000 2017
# 58      7743    117302  Customer     True  Tue Oct 31 22:53:04 +0000 2017
#
#                                                  text  response_tweet_id  \
# 6           @sprintcare is the worst customer service             9,6,10
# 22  @115714 @sprintcare how can I get in touch wit...  1,29,11,29,61,297
# 39  @sprintcare mine and my brothers data is barel...               3176
# 52  @sprintcare @115714 thinking about upgrading m...               5522
# 58  @115714  @sprintcare &amp; she hung up the pho...               7742
#
#     in_response_to_tweet_id
# 6                       NaN
# 22                      NaN
# 39                      NaN
# 52                      NaN
# 58                      NaN

# %%
conversation_starters_df.shape
# Out:
# (917, 8)

# %% [markdown]
# ## Trace conversations
#
# ### Subtask:
# For the first few conversation starters, trace the subsequent tweets using `tweet_id`, `response_tweet_id`, and `in_response_to_tweet_id` to build complete conversation threads.

# %% [markdown]
# **Reasoning**:
# Iterate through the first 20 conversation starters and trace their replies to build complete conversation threads.

# %%
conversations = []
for index, starter_tweet in conversation_starters_df.iterrows():
    conversation = [starter_tweet]
    current_tweet_id = starter_tweet['tweet_id']

    while True:
        next_tweet = df[df['in_response_to_tweet_id'] == current_tweet_id]
        if not next_tweet.empty:
            # Assuming there's only one reply per tweet in a simple thread
            current_tweet = next_tweet.iloc[0]
            conversation.append(current_tweet)
            current_tweet_id = current_tweet['tweet_id']
        else:
            break
    conversations.append(conversation)

# Display the first conversation as an example
if conversations:
    print("First Conversation Thread:")
    for tweet in conversations[0]:
        display(tweet)
# Out:
# First Conversation Thread:
# tweet_id                                                           8
# author_id                                                     115712
# role                                                        Customer
# inbound                                                         True
# created_at                            Tue Oct 31 21:45:10 +0000 2017
# text                       @sprintcare is the worst customer service
# response_tweet_id                                             9,6,10
# in_response_to_tweet_id                                          NaN
# Name: 6, dtype: object
# tweet_id                                                                   6
# author_id                                                         sprintcare
# role                                                        Service Provider
# inbound                                                                False
# created_at                                    Tue Oct 31 21:46:24 +0000 2017
# text                       @115712 Can you please send us a private messa...
# response_tweet_id                                                        5,7
# in_response_to_tweet_id                                                  8.0
# Name: 5, dtype: object
# tweet_id                                                5
# author_id                                          115712
# role                                             Customer
# inbound                                              True
# created_at                 Tue Oct 31 21:49:35 +0000 2017
# text                                   @sprintcare I did.
# response_tweet_id                                       4
# in_response_to_tweet_id                               6.0
# Name: 4, dtype: object
# tweet_id                                                                   4
# author_id                                                         sprintcare
# role                                                        Service Provider
# inbound                                                                False
# created_at                                    Tue Oct 31 21:54:49 +0000 2017
# text                       @115712 Please send us a Private Message so th...
# response_tweet_id                                                          3
# in_response_to_tweet_id                                                  5.0
# Name: 3, dtype: object
# tweet_id                                                                   3
# author_id                                                             115712
# role                                                                Customer
# inbound                                                                 True
# created_at                                    Tue Oct 31 22:08:27 +0000 2017
# text                       @sprintcare I have sent several private messag...
# response_tweet_id                                                          1
# in_response_to_tweet_id                                                  4.0
# Name: 2, dtype: object
# tweet_id                                                                   1
# author_id                                                         sprintcare
# role                                                        Service Provider
# inbound                                                                False
# created_at                                    Tue Oct 31 22:10:47 +0000 2017
# text                       @115712 I understand. I would like to assist y...
# response_tweet_id                                                          2
# in_response_to_tweet_id                                                  3.0
# Name: 0, dtype: object
# tweet_id                                                               2
# author_id                                                         115712
# role                                                            Customer
# inbound                                                             True
# created_at                                Tue Oct 31 22:11:45 +0000 2017
# text                       @sprintcare and how do you propose we do that
# response_tweet_id                                                    NaN
# in_response_to_tweet_id                                              1.0
# Name: 1, dtype: object

# %% [markdown]
# ## Structure the first 20 conversations
#
# ### Subtask:
# Organize the identified tweets into the first 20 distinct conversation structures.

# %% [markdown]
# **Reasoning**:
# Create a list to store the structured conversations and iterate through the traced conversations to organize them into a structured format.

# %%
import json
import numpy as np

# Custom encoder to handle NumPy types, including booleans
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.bool_):
            return bool(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

structured_conversations = []

for i, conversation_thread in enumerate(conversations):  # Process all conversations
    structured_thread = {
        'conversation_number': i + 1,
        'tweets': []
    }
    for tweet in conversation_thread:
        structured_thread['tweets'].append({
            'tweet_id': tweet['tweet_id'],
            'author_id': tweet['author_id'],
            'role': tweet['role'],
            'inbound': tweet['inbound'],
            'created_at': tweet['created_at'],
            'text': tweet['text']
        })
    structured_conversations.append(structured_thread)

# Display the first structured conversation as an example
if structured_conversations:
    print("First Structured Conversation:")
    # Print the dictionary representation for clarity
    print(json.dumps(structured_conversations[0], indent=4, cls=NpEncoder))
# Out:
# First Structured Conversation:
# {
#     "conversation_number": 1,
#     "tweets": [
#         {
#             "tweet_id": 8,
#             "author_id": "115712",
#             "role": "Customer",
#             "inbound": true,
#             "created_at": "Tue Oct 31 21:45:10 +0000 2017",
#             "text": "@sprintcare is the worst customer service"
#         },
#         {
#             "tweet_id": 6,
#             "author_id": "sprintcare",
#             "role": "Service Provider",
#             "inbound": false,
#             "created_at": "Tue Oct 31 21:46:24 +0000 2017",
#             "text": "@115712 Can you please send us a private message, so that I can gain further details about your account?"
#         },
#         {
#             "tweet_id": 5,
#             "author_id": "115712",
#             "role": "Customer",
#             "inbound": true,
#             "created_at": "Tue Oct 31 21:49:35 +0000 2017",
#             "text": "@sprintcare I did."
#         },
#         {
#             "tweet_id": 4,
#             "author_id": "sprintcare",
#             "role": "Service Provider",
#             "inbound": false,
#             "created_at": "Tue Oct 31 21:54:49 +0000 2017",
#             "text": "@115712 Please send us a Private Message so that we can further assist you. Just click \u2018Message\u2019 at the top of your profile."
#         },
#         {
#             "tweet_id": 3,
#             "author_id": "115712",
#             "role": "Customer",
#             "inbound": true,
#             "created_at": "Tue Oct 31 22:08:27 +0000 2017",
#             "text": "@sprintcare I have sent several private messages and no one is responding as usual"
#         },
#         {
#             "tweet_id": 1,
#             "author_id": "sprintcare",
#             "role": "Service Provider",
#             "inbound": false,
#             "created_at": "Tue Oct 31 22:10:47 +0000 2017",
#             "text": "@115712 I understand. I would like to assist you. We would need to get you into a private secured link to further assist."
#         },
#         {
#             "tweet_id": 2,
#             "author_id": "115712",
#             "role": "Customer",
#             "inbound": true,
#             "created_at": "Tue Oct 31 22:11:45 +0000 2017",
#             "text": "@sprintcare and how do you propose we do that"
#         }
#     ]
# }

# %% [markdown]
# ## Display the first 20 conversations
#
# ### Subtask:
# Show the content of the first 20 conversations.

# %% [markdown]
# **Reasoning**:
# Iterate through the structured conversations and print the details of each tweet in a readable format.

# %%
for i, conversation_thread_dict in enumerate(structured_conversations):
    print(f"Conversation {conversation_thread_dict['conversation_number']}:")
    for tweet in conversation_thread_dict['tweets']:
        print(f"  Author: {tweet['author_id']}")
        print(f"  Inbound: {tweet['inbound']}")
        print(f"  Created At: {tweet['created_at']}")
        print(f"  Text: {tweet['text']}")
        print("-" * 2)
# Out:
# Conversation 1:
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 21:45:10 +0000 2017
#   Text: @sprintcare is the worst customer service
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 21:46:24 +0000 2017
#   Text: @115712 Can you please send us a private message, so that I can gain further details about your account?
# --
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 21:49:35 +0000 2017
#   Text: @sprintcare I did.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 21:54:49 +0000 2017
#   Text: @115712 Please send us a Private Message so that we can further assist you. Just click ‘Message’ at the top of your profile.
# --
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 22:08:27 +0000 2017
#   Text: @sprintcare I have sent several private messages and no one is responding as usual
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 22:10:47 +0000 2017
#   Text: @115712 I understand. I would like to assist you. We would need to get you into a private secured link to further assist.
# --
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 22:11:45 +0000 2017
#   Text: @sprintcare and how do you propose we do that
# --
# Conversation 2:
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 22:24:51 +0000 2017
#   Text: @115714 @sprintcare how can I get in touch with someone that matters at Spring Corporate
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 22:26:44 +0000 2017
#   Text: @115712 Just click ‘Message’ at the top of your profile. We're always here and eager to assist.
# --
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 22:30:09 +0000 2017
#   Text: @sprintcare I've sent several private messages!!! and no one responds!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 22:34:30 +0000 2017
#   Text: @115712 Do you have a good contact number where you can be reached?
# --
#   Author: 115712
#   Inbound: True
#   Created At: Tue Oct 31 22:34:55 +0000 2017
#   Text: @sprintcare I sent it twice now to apparently noone!
# --
# Conversation 3:
#   Author: 116445
#   Inbound: True
#   Created At: Tue Oct 31 22:55:37 +0000 2017
#   Text: @sprintcare mine and my brothers data is barely working, we have full signal but nothing is loading &amp; when it does load its very slow, help!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 22:58:30 +0000 2017
#   Text: @116445 You’ve reached the right place, please shoot us a DM, in order for us to further assist you. -AA
# --
#   Author: 116445
#   Inbound: True
#   Created At: Tue Oct 31 23:09:03 +0000 2017
#   Text: @sprintcare Just sent a DM
# --
# Conversation 4:
#   Author: 117001
#   Inbound: True
#   Created At: Tue Oct 31 23:12:51 +0000 2017
#   Text: @sprintcare @115714 thinking about upgrading my wife’s iPhone 6.  What is your best offer?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 23:16:16 +0000 2017
#   Text: @117001 Hey! We would need to see what offers are available to you. Send us a DM so we can further assist you. -CD
# --
# Conversation 5:
#   Author: 117302
#   Inbound: True
#   Created At: Tue Oct 31 22:53:04 +0000 2017
#   Text: @115714  @sprintcare &amp; she hung up the phone on me. I want my money back. Or else the whole world gonna know
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 23:36:56 +0000 2017
#   Text: @117302 Hi there! Can you tell us the reason for the credit? Can you also join us in a DM so we can assist you? -KW
# --
# Conversation 6:
#   Author: 117303
#   Inbound: True
#   Created At: Tue Oct 31 22:43:39 +0000 2017
#   Text: @sprintcare is there an outage in the Minneapolis/St. Paul Minnesota area?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 23:34:08 +0000 2017
#   Text: @117303 Thank you for reaching out to us. Please send us a Direct Message, so that we can further assist you. -C.H
# --
# Conversation 7:
#   Author: 117592
#   Inbound: True
#   Created At: Tue Oct 31 23:28:34 +0000 2017
#   Text: @sprintcare @115714 the sad part is i’m at my own house. and everyone else that i live with, has service. https://t.co/OHhmkBfr0B
# --
#   Author: 117592
#   Inbound: True
#   Created At: Tue Oct 31 23:30:23 +0000 2017
#   Text: @sprintcare @115714 never mind i can’t even send txts. https://t.co/iWFDZrLDzF
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 23:52:12 +0000 2017
#   Text: @117592 We will like to take a look into this for you. Shoot us a DM to assist. -JA
# --
#   Author: 117592
#   Inbound: True
#   Created At: Tue Oct 31 23:52:48 +0000 2017
#   Text: @sprintcare well i just tried calling you guys but it automatically fails. i had this problem an hour ago and it’s back. just messaged you.
# --
# Conversation 8:
#   Author: 117733
#   Inbound: True
#   Created At: Tue Oct 31 01:59:15 +0000 2017
#   Text: @67723 Could you confirm @115714 falls within your office's jurisdiction?  I have been defrauded, @sprintcare refuses to mediate.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 02:23:54 +0000 2017
#   Text: @117733 Hello Michael! We will send you a DM shortly.
# --
#   Author: 117733
#   Inbound: True
#   Created At: Tue Oct 31 21:06:53 +0000 2017
#   Text: @sprintcare @67723
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 31 21:12:16 +0000 2017
#   Text: @117733 We regret to hear of your recent experience and we want to help. We will reach out to you momentarily to address your account concerns.
# --
#   Author: 117733
#   Inbound: True
#   Created At: Tue Oct 31 23:46:19 +0000 2017
#   Text: @sprintcare Still nothing 2 hours later, our definitions of "momentarily" are not aligned.  Ashley @ 312.890.7112 - please contact. FYI@Koster4Missouri
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 00:01:28 +0000 2017
#   Text: @117733 We apologize for the delay. Your assigned analyst will be contacting you shortly.
# --
#   Author: 117733
#   Inbound: True
#   Created At: Wed Nov 01 05:48:02 +0000 2017
#   Text: @sprintcare Again, contact is Ashley Wisniewski - 312.890.7112.  She IS an account holder.
# --
# Conversation 9:
#   Author: 118025
#   Inbound: True
#   Created At: Wed Nov 01 00:26:17 +0000 2017
#   Text: @sprintcare is there any news on when the WiFi calling Plus will be available for the Note8?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 00:43:18 +0000 2017
#   Text: @118025 Currently, the Note 8 does have Wi-Fi Calling. Send us a DM so we can provide you with the steps to activate it. -KW
# --
# Conversation 10:
#   Author: 118160
#   Inbound: True
#   Created At: Wed Nov 01 00:49:44 +0000 2017
#   Text: @sprintcare WTF THEY JUST HUNG UP ON ME AGAIN!!!!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 00:52:07 +0000 2017
#   Text: @118160 We want to help you, in order for us to do so, you'll need to send us a Direct Message so we can better assist. -AG
# --
# Conversation 11:
#   Author: 118588
#   Inbound: True
#   Created At: Wed Nov 01 01:21:58 +0000 2017
#   Text: @sprintcare I had my iPhone replaced by Apple because it was defective. Now I can’t receive SMS messages from Verizon numbers. No one has been able to help me out. Hoping you can! I have reset my network settings. I can send SMS and receive MMS from Verizon numbers.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 01:39:29 +0000 2017
#   Text: @118588 Hey Laura! Don't worry, we're here for you. How long have you had this issue? -CO
# --
#   Author: 118588
#   Inbound: True
#   Created At: Wed Nov 01 01:41:24 +0000 2017
#   Text: @sprintcare I had the phone replaced last Tuesday. So, a week.
# --
# Conversation 12:
#   Author: 118160
#   Inbound: True
#   Created At: Wed Nov 01 01:40:47 +0000 2017
#   Text: @sprintcare &amp; @115714 ARE COMPLETE LIERS! They force you to keep the service and won’t disconnect! #BlackTwitter #America #smartphones
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 01:45:32 +0000 2017
#   Text: @118160 @115714 Thank you for taking my call. I do hope that the transfer to the other department was successful. -AG
# --
#   Author: 118160
#   Inbound: True
#   Created At: Wed Nov 01 01:51:13 +0000 2017
#   Text: @sprintcare @115714 Don’t lie for Twitter
# --
# Conversation 13:
#   Author: 119509
#   Inbound: True
#   Created At: Wed Nov 01 03:17:47 +0000 2017
#   Text: @sprintcare I HAVE A BIG ISSUE WITH YA'LL HELLO
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 03:25:31 +0000 2017
#   Text: @119509 Hey there! What seems to be the issue today? -MM
# --
# Conversation 14:
#   Author: 119894
#   Inbound: True
#   Created At: Wed Nov 01 04:11:59 +0000 2017
#   Text: @sprintcare How do I contact a live customer service rep? Calling funnels me into an endless phone menu
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 04:36:47 +0000 2017
#   Text: @119894 We are here to help! Please send us a Direct Message, so that we can further assist you. - LV. https://t.co/rMApsV8PQY
# --
# Conversation 15:
#   Author: 119941
#   Inbound: True
#   Created At: Wed Nov 01 04:52:12 +0000 2017
#   Text: @sprintcare why are my words showing symbols instead of the words ??? Tf
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 04:56:50 +0000 2017
#   Text: @119941 Hi there! We saw your tweet and would like to assist you. Please send us a DM and follow us to further assist you. -GM.
# --
#   Author: 119941
#   Inbound: True
#   Created At: Wed Nov 01 04:58:13 +0000 2017
#   Text: @sprintcare Check your DMs.. thanks
# --
# Conversation 16:
#   Author: 120573
#   Inbound: True
#   Created At: Wed Nov 01 07:19:49 +0000 2017
#   Text: @sprintcare I’m not even a customer yet and I’ve gotten the run around. 7250 S Cicero Ave store is a joke. Fire everyone
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 07:23:18 +0000 2017
#   Text: @120573 We do apologize for the experience in which you had at our store. What seems to be the issue? -MM
# --
#   Author: 120573
#   Inbound: True
#   Created At: Wed Nov 01 07:37:15 +0000 2017
#   Text: @sprintcare Also, that store is playing load music that makes it hard to hear. It’s a store not a dance club.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 07:44:36 +0000 2017
#   Text: @120573 To activate your device, you can either visit the link provided, https://t.co/cLSUsitfDr or call 866-782-8777 for further assistance. -MM
# --
# Conversation 17:
#   Author: 120645
#   Inbound: True
#   Created At: Wed Nov 01 07:26:53 +0000 2017
#   Text: @sprintcare why is all my text from earlier today just coming in? Used to work for Sprint &amp; could never understand it?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 07:36:35 +0000 2017
#   Text: @120645 Hi there! We saw your tweet and would like to assist you. Please send us a DM and follow to further assist. -GM.
# --
# Conversation 18:
#   Author: 121422
#   Inbound: True
#   Created At: Wed Nov 01 09:41:07 +0000 2017
#   Text: I need somebody from @sprintcare to answer a question I have ASAP
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 09:44:17 +0000 2017
#   Text: @121422 Hey there! Questions? You’ve come to the right place. Please let us know how we can be of assistance today. - RC
# --
#   Author: 121422
#   Inbound: True
#   Created At: Wed Nov 01 18:45:12 +0000 2017
#   Text: @sprintcare Ok can y’all dm me or something
# --
# Conversation 19:
#   Author: 121553
#   Inbound: True
#   Created At: Sun Nov 05 17:55:25 +0000 2017
#   Text: @sprintcare Just had the worst support experience ever at a Sprint store. Zero interest in helping me and was completely rude.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 05 18:03:19 +0000 2017
#   Text: @121553 we hate to hear this and apologize for the inconvenience. But is there something I can help you with today.
# --
#   Author: 121553
#   Inbound: True
#   Created At: Sun Nov 05 18:11:34 +0000 2017
#   Text: @sprintcare I damaged a phone and need a replacement, the staff member was zero help and was completely rude in helping. I am very upset about this, I have been a sprint customer for 16 years. Is there a way to make an official complaint?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 05 18:15:25 +0000 2017
#   Text: @121553 will address it. Also I'm going to direct message you some information about getting your phone replaced.
# --
# Conversation 20:
#   Author: 121794
#   Inbound: True
#   Created At: Tue Nov 07 17:17:24 +0000 2017
#   Text: Hey @sprintcare bouncing between 1 bar &amp; no service for 2 days. 94th Terrace &amp; Nall Overland Park, KS 66207.  And no, it’s not my phone.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Nov 07 17:24:10 +0000 2017
#   Text: @121794 We apologize for the issues you have experienced. DM your phone number so that we may research your concerns and reach out.
# --
# Conversation 21:
#   Author: 121800
#   Inbound: True
#   Created At: Tue Nov 07 17:07:25 +0000 2017
#   Text: @sprintcare you’re online chat is a mess,  need help but yet they can’t help or been on hold waiting for them to reply and need help but no
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Nov 07 17:10:51 +0000 2017
#   Text: @121800 Hello there! Thank you for reaching out to us today. How can I assist you today?
# --
#   Author: 121800
#   Inbound: True
#   Created At: Tue Nov 07 17:12:18 +0000 2017
#   Text: @sprintcare Been trying to get help with things from support and they rather take 5 minutes to answer or been on holdnwaiting to connext for a long time
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Nov 07 17:15:36 +0000 2017
#   Text: @121800 To continue our conversation can you please send a private message, so that I can gain further details about your account?
# --
# Conversation 22:
#   Author: 122740
#   Inbound: True
#   Created At: Wed Nov 01 11:49:09 +0000 2017
#   Text: Who can ship me a 256 gb Space Gray IPhone X on Launch day? @117735 @sprintcare @TMobileHelp @VerizonSupport @AppleSupport
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 11:54:02 +0000 2017
#   Text: @122740 Thanks 4 reaching out Jack, please visit https://t.co/nUZ2kUiomr &amp; https://t.co/lHDQ076Flh for our wonderful options. Sprint. -MM
# --
# Conversation 23:
#   Author: 122641
#   Inbound: True
#   Created At: Wed Nov 01 12:06:40 +0000 2017
#   Text: @sprintcare I'd never recommended @115714 to anyone. The customer service sucks and my service is super spotty I never get texts
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 12:10:37 +0000 2017
#   Text: @122641 @115714 Please let me know if that helps. -DS
# --
# Conversation 24:
#   Author: 122830
#   Inbound: True
#   Created At: Wed Nov 01 12:00:06 +0000 2017
#   Text: @sprintcare Seriously, it's been two months since Irma and still having technical issues with texts and messaging...just awful
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 12:03:18 +0000 2017
#   Text: @122830 Something isn't right, please send us a Direct Message, so that we can further assist you. YP
# --
#   Author: 122830
#   Inbound: True
#   Created At: Wed Nov 01 12:07:26 +0000 2017
#   Text: @sprintcare Just did...thanks.
# --
# Conversation 25:
#   Author: 123294
#   Inbound: True
#   Created At: Wed Nov 22 18:15:41 +0000 2017
#   Text: @sprintcare just switched ownership of my wife's account to mine and it takes 5 days!? Seriously?  All the other carriers are instant.  What's the deal???
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 22 18:23:13 +0000 2017
#   Text: @123294 You may go to https://t.co/aWiBALYzog.
# •Once submitted, wait 24 hours and tell both customers to call 8558084185 to complete change of ownership.
# •Change of ownership team is available Monday - Saturday 8 a.m. - 9 p.m. Central time. -MB
# --
#   Author: 123294
#   Inbound: True
#   Created At: Wed Nov 22 18:24:33 +0000 2017
#   Text: @sprintcare Both customers (my wife and I) both completed the online forms for change of ownership.  So we still need to call to finalize it?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 22 18:28:05 +0000 2017
#   Text: @123294 Please send us a DM, so that we can further assist you. - LP
# --
# Conversation 26:
#   Author: 123422
#   Inbound: True
#   Created At: Wed Nov 01 12:06:40 +0000 2017
#   Text: @sprintcare I switched to Sprint only to find their network won’t allow you to use data while on a call. Canceled same day &amp; now got bill?!!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 13:01:32 +0000 2017
#   Text: @123422 Thanks for reaching out. Please send us a DM and also follow us so we can further assist. -MM
# --
# Conversation 27:
#   Author: 124216
#   Inbound: True
#   Created At: Wed Nov 01 14:05:29 +0000 2017
#   Text: Hey @115714 @sprintcare The HTC Charger for my HTC wont charge my phone the orange light is on and charge level says 32%
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 14:15:49 +0000 2017
#   Text: @124216 Visit one of our nearest Sprint Repair stores so they can have a look at the device and the charger for you. :) -AS
# --
# Conversation 28:
#   Author: 124217
#   Inbound: True
#   Created At: Wed Nov 01 14:12:20 +0000 2017
#   Text: Is it normal to end a convo with a hang-up? By an agent and then a manager? Case # 186228125 @115714 @sprintcare @124218
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 14:15:07 +0000 2017
#   Text: @124217 No, it isn't right. Not acceptable! We apologize for the treatment that you had received. Please send us a DM right away. -CO
# --
#   Author: 124217
#   Inbound: True
#   Created At: Wed Nov 01 14:22:13 +0000 2017
#   Text: @sprintcare Will do.
# --
# Conversation 29:
#   Author: 124541
#   Inbound: True
#   Created At: Mon Oct 30 22:32:48 +0000 2017
#   Text: @115714 @sprintcare why hasn’t my iPhone X shipped yet. I was supposed to get it on launch day.
# --
#   Author: 124542
#   Inbound: True
#   Created At: Tue Oct 31 16:29:29 +0000 2017
#   Text: @124541 @115714 @sprintcare Launch day is Nov 3rd.
# --
#   Author: 124541
#   Inbound: True
#   Created At: Tue Oct 31 19:41:05 +0000 2017
#   Text: @124542 @115714 @sprintcare Did you not read my response to the last person who sent that. You have 2 ship a phone before it can arrive. Others have already gotten info
# --
#   Author: 124542
#   Inbound: True
#   Created At: Wed Nov 01 09:22:40 +0000 2017
#   Text: @124541 @115714 @sprintcare Again. Launch day is Nov 3rd. You paid for overnight shipping. The physical phone will not leave the physical warehouse until Thursday.
# --
#   Author: 124541
#   Inbound: True
#   Created At: Wed Nov 01 14:46:34 +0000 2017
#   Text: @124542 @115714 @sprintcare Again, others have gotten shipping information so I am just trying to clarify. Also, I’m asking sprint. Show me your sprint employee info
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 14:51:11 +0000 2017
#   Text: @124541 Hey, just to clarify did you receive an email with confirmation for your preorder? -KA
# --
#   Author: 124541
#   Inbound: True
#   Created At: Wed Nov 01 14:52:17 +0000 2017
#   Text: @sprintcare I did not. However, you guys are supposed to give me a call at 4  thanks 🙂
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 14:55:30 +0000 2017
#   Text: @124541 Sure! You would be contacted at the time requested. We look forward to speak with you. Enjoy your day! -KA
# --
# Conversation 30:
#   Author: 124756
#   Inbound: True
#   Created At: Wed Nov 01 14:48:03 +0000 2017
#   Text: @sprintcare I had signed up for a MagicBox, and was told I was eligible to receive one.  Now being told I have an Airave and ineligble.
# --
#   Author: 124756
#   Inbound: True
#   Created At: Wed Nov 01 14:49:25 +0000 2017
#   Text: @sprintcare Is there any way I can return the Airave and then submit the order for the MagicBox?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 15:09:11 +0000 2017
#   Text: @124756 Visit https://t.co/X1DpDgk1EU to find the nearest store to you. Sprint Cares! -  CF
# --
# Conversation 31:
#   Author: 124985
#   Inbound: True
#   Created At: Wed Nov 01 15:12:28 +0000 2017
#   Text: @sprintcare hey can you send me my iPhone x sooner thanks
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 15:16:52 +0000 2017
#   Text: @124985 You've got your place in line, you're part of the club now. Please visit https://t.co/E2O5xci9LH site to check status. -DJ
# --
#   Author: 124985
#   Inbound: True
#   Created At: Wed Nov 01 15:17:26 +0000 2017
#   Text: @sprintcare ☹️☹️☹️ I want it sooner than the 3rd week I’m gonna cry.
# --
# Conversation 32:
#   Author: 125239
#   Inbound: True
#   Created At: Wed Nov 01 15:40:24 +0000 2017
#   Text: I need a @sprintcare customer service agent😩😩😩
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 15:41:59 +0000 2017
#   Text: @125239 Good morning! How may I be of assistance? -SW
# --
# Conversation 33:
#   Author: 125239
#   Inbound: True
#   Created At: Wed Nov 01 15:46:32 +0000 2017
#   Text: @sprintcare can someone call me please. I am a customer in distress😩😩😩i am being overcharged i think
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 15:47:56 +0000 2017
#   Text: @125239 Okay. Send us a DM so that we can get that call set up for you. -SW
# --
#   Author: 125239
#   Inbound: True
#   Created At: Wed Nov 01 15:51:29 +0000 2017
#   Text: @sprintcare thanks ☺️
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 15:59:00 +0000 2017
#   Text: @125239 Thank you for using the Secure Messaging System. We will continue the conversation there. -SW
# --
# Conversation 34:
#   Author: 125736
#   Inbound: True
#   Created At: Wed Nov 01 16:05:53 +0000 2017
#   Text: In the @115714 store cancellimg my account and @sprintcare is so bad they hung up on me and the guy who works at this location #sprintsucks
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 16:11:40 +0000 2017
#   Text: @125736 Jay, we really hate to hear that you want to leave Sprint; is there anything that we can do to turn this around? -CDE
# --
# Conversation 35:
#   Author: 125913
#   Inbound: True
#   Created At: Sun Nov 26 00:49:35 +0000 2017
#   Text: Really sick of paying 100 a month for dropped calls and no internet service. @sprintcare is there anything you will do for me?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 26 00:57:01 +0000 2017
#   Text: @125913 Can you please send me a DM so that I can take a look at your concern? -BJ https://t.co/rMApsV8PQY
# --
# Conversation 36:
#   Author: 125914
#   Inbound: True
#   Created At: Sun Nov 26 00:47:17 +0000 2017
#   Text: @AppleSupport  @sprintcare why isn’t anyone willing to help !?!?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 26 00:49:07 +0000 2017
#   Text: @125914 Please send us a Direct Message, so that we can further assist you. -OM https://t.co/rMApsV8PQY
# --
#   Author: 125914
#   Inbound: True
#   Created At: Sun Nov 26 00:50:06 +0000 2017
#   Text: @sprintcare I did and called
# --
# Conversation 37:
#   Author: 125928
#   Inbound: True
#   Created At: Sun Nov 26 00:09:44 +0000 2017
#   Text: @115714 @sprintcare Horrible service...ported 3 wks ago...not able to make single call. Running between cc, store and apple care. Will transfer my service back sigh!!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 26 00:28:09 +0000 2017
#   Text: @125928 This is not the type of experience that we want you to have. We would like to know about what exactly is happening, In order for us to do it, please follow us and send us a DM. -AM.
# --
#   Author: 125928
#   Inbound: True
#   Created At: Sun Nov 26 18:28:35 +0000 2017
#   Text: @sprintcare Sent you all the details in a DM. Please help!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 26 18:38:19 +0000 2017
#   Text: @125928 Hi there! What can I help with today? Please send us a Direct Message, so that we can further assist you. -S M
# --
#   Author: 125928
#   Inbound: True
#   Created At: Sun Nov 26 18:56:25 +0000 2017
#   Text: @sprintcare I already sent you a detailed Direct Message.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 26 19:08:03 +0000 2017
#   Text: @125928 Did you send it through Twitter or Facebook? If it was through Facebook, what's your profile name there? -S M
# --
#   Author: 125928
#   Inbound: True
#   Created At: Sun Nov 26 20:54:43 +0000 2017
#   Text: @sprintcare Thru Twitter
# --
# Conversation 38:
#   Author: 126206
#   Inbound: True
#   Created At: Wed Nov 01 16:38:16 +0000 2017
#   Text: @sprintcare  I am not getting text messages, my phone will randomly drop calls or say no service. I am not the only one having this issue. So what's going on?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 16:40:33 +0000 2017
#   Text: @126206 We definitely want you to have amazing coverage! Shoot us a DM to take a look at the coverage in your area! -Maria Q
# --
# Conversation 39:
#   Author: 125239
#   Inbound: True
#   Created At: Wed Nov 01 16:39:30 +0000 2017
#   Text: @sprintcare SW @ sprint is amazingggg, thank you so much🙏🏾
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 16:45:16 +0000 2017
#   Text: @125239 Awww shucks! LOL Thanks for letting me help you. Have a great rest of your week!! :) -SW
# --
# Conversation 40:
#   Author: 127280
#   Inbound: True
#   Created At: Wed Nov 01 17:14:26 +0000 2017
#   Text: @SprintCare How do you activate the 7-day speed pass while abroad in Thailand?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 17:26:32 +0000 2017
#   Text: @127280 Are you currently at this location or thinking of visiting? When you arrive, you are greeted with a message with these options. - JF
# --
#   Author: 127280
#   Inbound: True
#   Created At: Wed Nov 01 17:31:32 +0000 2017
#   Text: @sprintcare I arrive Saturday. I'll await the message on my phone then. Thanks for clarifying!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 17:35:36 +0000 2017
#   Text: @127280 You're welcome. Do have a good day and thank you for choosing Sprint. :) -AS
# --
#   Author: 127280
#   Inbound: True
#   Created At: Sat Nov 04 06:14:16 +0000 2017
#   Text: @sprintcare I'm in Hong Kong now and it didn't ask me to purchase data. It sent a text saying it's 3-cents/MB please advise
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Nov 04 06:37:06 +0000 2017
#   Text: @127280 ... you to contact our International Department dialing 888-226-7212 or https://t.co/aN4RVhDy8I. (2/2) -LR.
# --
#   Author: 127280
#   Inbound: True
#   Created At: Sun Nov 05 02:42:55 +0000 2017
#   Text: @sprintcare I just got on global roaming and it never asked me to upgrade to high speed. How do I force it manually? In Bangkok already
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Nov 05 04:03:01 +0000 2017
#   Text: @127280 Please send us a DM, we would love to further assist you! -PB. https://t.co/rMApsV8PQY
# --
# Conversation 41:
#   Author: 128200
#   Inbound: True
#   Created At: Wed Nov 01 18:44:50 +0000 2017
#   Text: Hey @115714 @sprintcare are there any outages in Topeka KS for LTE? My service has been spotty everywhere I go today.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 18:55:18 +0000 2017
#   Text: @128200 Hi Richard ,I have reviewed the network in your area and saw that it is working well. Send me DM for further assistance. -KJ
# --
# Conversation 42:
#   Author: 128384
#   Inbound: True
#   Created At: Wed Nov 01 18:21:20 +0000 2017
#   Text: @sprintcare can you help me?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:11:31 +0000 2017
#   Text: @128384 You’ve reached the right place! What's going on? Shoot us a DM. -KC
# --
# Conversation 43:
#   Author: 128388
#   Inbound: True
#   Created At: Wed Nov 01 17:52:55 +0000 2017
#   Text: @sprintcare Please don't make me find a new provider who makes me feel wanted. I've never had a problem with @115714. I don't want one now.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:01:40 +0000 2017
#   Text: @128388 Can you please send a private message, so that I can gain further details about your account?
# --
#   Author: 128388
#   Inbound: True
#   Created At: Wed Nov 01 19:17:57 +0000 2017
#   Text: @sprintcare I'd be happy to, but don't you have to follow me before I can do so?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:24:01 +0000 2017
#   Text: @128388 You would need to follow us and then send the private message.
# --
#   Author: 128388
#   Inbound: True
#   Created At: Wed Nov 01 19:25:51 +0000 2017
#   Text: @sprintcare I'm already following you. I did that this morning.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:27:18 +0000 2017
#   Text: @128388 Ok great. . Just click ‘Message’ at the top of your profile. We're always here and eager to assist.
# --
# Conversation 44:
#   Author: 128568
#   Inbound: True
#   Created At: Wed Nov 01 19:02:23 +0000 2017
#   Text: @sprintcare if this "EMP test" gonna kill my service, then I can keep my money for this month right ? 🤔😂
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:20:18 +0000 2017
#   Text: @128568 Please send us a DM so we can chat further. -ES
# --
# Conversation 45:
#   Author: 128572
#   Inbound: True
#   Created At: Wed Nov 01 19:09:29 +0000 2017
#   Text: @115714 &amp; @sprintcare I guess after being with you guys for over 12 years, it’s time to cut the cord. #iNeedBetterCustomerService
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 19:15:06 +0000 2017
#   Text: @__mixxedmami__ We hate to hear you feel that way &amp; definitely don't want to lose you - Can you please DM us with the specifics?? -CDE
# --
# Conversation 46:
#   Author: 129095
#   Inbound: True
#   Created At: Wed Nov 01 20:06:53 +0000 2017
#   Text: @sprintcare how can I get my account number? Having issues logging on to the Sprint app
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 20:09:56 +0000 2017
#   Text: @129095 We would love to assist you with this issue. Please send us a Direct Message, so that we can further assist you. -TR
# --
# Conversation 47:
#   Author: 129669
#   Inbound: True
#   Created At: Wed Nov 01 20:55:13 +0000 2017
#   Text: @sprintcare 17363 can't rcv calls today think there's a prob with tower. Mind going numb dealing w/chat srvc
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 20:59:41 +0000 2017
#   Text: @129669 Please send us a Direct Message, so that we can further assist you. - JS
# --
# Conversation 48:
#   Author: 129672
#   Inbound: True
#   Created At: Wed Nov 01 20:48:16 +0000 2017
#   Text: Last minute - time to switch to @sprintcare @115714 or @ATT if they still offer promos to help me switch from @115911
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 20:49:28 +0000 2017
#   Text: @129672 Hey! We'd love to have you join the Sprint family. You can check out our promotions here: https://t.co/cMnRTJIhW7! -CD
# --
#   Author: 129672
#   Inbound: True
#   Created At: Thu Nov 02 13:29:45 +0000 2017
#   Text: @sprintcare Will you help cancel my @115911 bill? I have two lines (phone &amp; apple watch)
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 02 14:11:59 +0000 2017
#   Text: @129672 Hey Jeremiah! Thank you for reaching out tot us. We'd be happy to assist you. Please send us a Direct Message. -CO
# --
#   Author: 129672
#   Inbound: True
#   Created At: Thu Nov 02 17:21:03 +0000 2017
#   Text: @sprintcare Ok will do thanks again for looking into assisting with my switch from @115911
# --
# Conversation 49:
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 20:59:15 +0000 2017
#   Text: Yo @sprintcare this dog has calls to make. Cam you fix the tower please.  Zip 17363 cross street is hill and church.  #woof
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:12:09 +0000 2017
#   Text: @130361 Hi Darcy, we'd be happy to assist you with your service issues. Please send us a DM so that we can further assist you. -MB
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:15:36 +0000 2017
#   Text: @sprintcare This dog doesn't do DMs. Just fix the tower. #ihavepeepstobarkat
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:21:09 +0000 2017
#   Text: @130361 We reviewed the coverage within ur location n we c that the tower is currently working. Send us a DM so that we can provide u with help. -MB
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:28:07 +0000 2017
#   Text: @sprintcare My owners work phone works just fine.  But that is an @ATT phone.  I guess they know what they are doing.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:30:12 +0000 2017
#   Text: @130361 We'd like to provide you with some troubleshooting steps to see if it'll help. -MB
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:34:16 +0000 2017
#   Text: @sprintcare No DM needed.  Your online peeps just said there is a tower issue after telling me there was none.  I can't handle the lies.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:36:09 +0000 2017
#   Text: @130361 If you change your mind, we'd be happy to assist you. -MB
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:36:48 +0000 2017
#   Text: @sprintcare I'm thinking about changing carriers.  Y'all stuff us not working.  Thanks for nothing.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:43:10 +0000 2017
#   Text: @130361 We'd hate to lose you as a customer, we'd appreciate the opportunity to assist you with your service issues. -MB
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:43:55 +0000 2017
#   Text: @sprintcare But you're not helping with the issue.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:47:37 +0000 2017
#   Text: @130361 I'll like to look into the issue and aim in obtaining a resolution. Please elaborate, and let's know what's going on. - AW
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:48:28 +0000 2017
#   Text: @sprintcare Everything on my phone works fine.  That is except for incoming calls.  I do not get them.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:49:56 +0000 2017
#   Text: @130361 Please DM us to further assist. - AW
# --
#   Author: 130361
#   Inbound: True
#   Created At: Wed Nov 01 21:51:25 +0000 2017
#   Text: @sprintcare Why? My wife did almost 30 minutes ago and y'all still have not responded.  Maybe @ATT would like to have my money.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Wed Nov 01 21:57:33 +0000 2017
#   Text: @130361 I can assure you we are willing to help resolve the issue.We'll like to run some troubleshooting steps on the device.Please DM to help! - AW
# --
# Conversation 50:
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 10:25:05 +0000 2017
#   Text: @115714 Community is creating content based on your questions, you ask, we answer!  #sprintcommunity https://t.co/uhIuPhOQBO
# --
#   Author: 132344
#   Inbound: True
#   Created At: Thu Nov 30 10:32:09 +0000 2017
#   Text: @sprintcare @115714 Can I connect my sprint iPhone on @126302 ?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 10:38:26 +0000 2017
#   Text: @132344 Hey there, Thanks for reaching out. for specifications on the devices compatible with MetroPCS you'd need to contact them. In case that it is compatible it will need to be unlocked by us, review our unlock policy here https://t.co/0lrOQ5qagh. -DC
# --
#   Author: 132344
#   Inbound: True
#   Created At: Thu Nov 30 10:39:56 +0000 2017
#   Text: @sprintcare Thank you!!!
# --
# Conversation 51:
#   Author: 132813
#   Inbound: True
#   Created At: Thu Nov 30 08:34:43 +0000 2017
#   Text: I think I am going to switch from t-mobile to Sprint I keep having problems with my service. @116447 @115913 @TMobileHelp @115911 @115714 @sprintcare
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 13:18:05 +0000 2017
#   Text: @132813 We'd love to have you as part of the Sprint family. Check us out at the following link. https://t.co/vRsxenjaBh Team @116447 https://t.co/IR1NMLcrCp
# --
# Conversation 52:
#   Author: 133667
#   Inbound: True
#   Created At: Thu Nov 30 12:08:51 +0000 2017
#   Text: I want the #iPhoneX I wonder do the @115714 @sprintcare store in Cape have em in stock? 🤔
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 12:16:01 +0000 2017
#   Text: @133667 Let's figure it out! Send me a DM so that I can further assist you. -ND
# --
# Conversation 53:
#   Author: 134196
#   Inbound: True
#   Created At: Thu Nov 30 10:26:51 +0000 2017
#   Text: @sprintcare @115714 not happy with false advertising. Ordered new iPhones online from you bc as said no activation fee if orders online. yet I get charged activation fees? Plz explain
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 13:15:21 +0000 2017
#   Text: @134196 I would be more than happy to review the fees for a resolution.  Please DM your contact information. https://t.co/rMApsV8PQY
# --
# Conversation 54:
#   Author: 134201
#   Inbound: True
#   Created At: Thu Nov 30 03:39:22 +0000 2017
#   Text: .@115714 @sprintcare stop selling the @134202 phone. These are the instructions for getting it to work "properly" on your network. What a fraud. https://t.co/BKtreewe39
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 03:58:51 +0000 2017
#   Text: @134201 We will be glad to have your analyst reach out to you in the morning.
# --
#   Author: 134201
#   Inbound: True
#   Created At: Thu Nov 30 03:59:47 +0000 2017
#   Text: @sprintcare I'm good, stop selling this phone you're doing your customers a disservice.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 13:09:54 +0000 2017
#   Text: @134201 If you need help please let us know. We regret that you were having problems.
# --
# Conversation 55:
#   Author: 134203
#   Inbound: True
#   Created At: Thu Nov 30 04:53:34 +0000 2017
#   Text: @sprintcare NEVER have been so blatantly disrespected by any company! If you know you wrongfully suspended my service why do y’all keep saying we attempted to call you...... THE PHONES ARE OFF
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 13:08:50 +0000 2017
#   Text: @134203 This is definitely not the type of feedback we like to hear. If you have any questions or need anything send us a DM we are here to help!
# --
# Conversation 56:
#   Author: 134923
#   Inbound: True
#   Created At: Thu Nov 30 13:59:01 +0000 2017
#   Text: @134924 @sprintcare Latest S8 update (SM-G955U, build number ending QJH) has broken fast charging (1). (2) when 100% wireless charging, screen keeps turning on and off ALL NIGHT LONG. Extremely annoying. Major, major issue. Help us!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 14:21:58 +0000 2017
#   Text: @134923 Send us a DM to further assist. - JM
# --
# Conversation 57:
#   Author: 134926
#   Inbound: True
#   Created At: Thu Nov 30 13:54:43 +0000 2017
#   Text: @sprintcare @115714 I was told no more towers in my area, coastal NC. Why? I don't want to go back to your competitors, but I may be forced to.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 14:13:55 +0000 2017
#   Text: @134926 We're constantly working to enhance our service. Please send us a Direct Message, so that we can further assist you. -PC
# --
#   Author: 134926
#   Inbound: True
#   Created At: Thu Nov 30 18:03:49 +0000 2017
#   Text: @sprintcare I've already done that...to no avail.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 19:21:17 +0000 2017
#   Text: @134926 We'd like to take a closer look into your concern, let us help resolute your issues. Just shoot us a DM, so we can step in to help. -BJ https://t.co/rMApsV8PQY
# --
# Conversation 58:
#   Author: 135657
#   Inbound: True
#   Created At: Thu Nov 30 13:45:10 +0000 2017
#   Text: 🖕 you @115714 @sprintcare  For a punk a** 84$ y'all on some 🐂💩 This how you treat a 15 year loyal customer? Having seconds 🤔 about renewing my contract https://t.co/Da3AvVUXE6
# --
#   Author: 135657
#   Inbound: True
#   Created At: Thu Nov 30 14:27:44 +0000 2017
#   Text: @115714 @sprintcare Now I don't owe y'all 💩 till next year. #MetroPCS looking real good right about now. https://t.co/GxABt4Wqu9
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:10:45 +0000 2017
#   Text: @135657 Good morning! Thank you for reaching out to us. Would you please send us a DM so we can further assist you today? Thank you. Ange L
# --
# Conversation 59:
#   Author: 135658
#   Inbound: True
#   Created At: Thu Nov 30 14:47:10 +0000 2017
#   Text: Hey @115714 @sprintcare your hot spot services near Gatesville, Texas are a joke. https://t.co/kHeuoOEU73
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:04:21 +0000 2017
#   Text: @135658 How long have you been experiencing these speeds? Does this happen when you're in this location exclusively? - JF
# --
#   Author: 135658
#   Inbound: True
#   Created At: Thu Nov 30 15:16:06 +0000 2017
#   Text: @sprintcare For about three days now, this location (North Fort Hood) sees huge amounts of traffic since it is the sole location for all deploying National Guard members for the entire country. Speeds get very slow during peak hours. And remain slow during low hours.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 21:15:47 +0000 2017
#   Text: @135658 Thanks for making us aware of this issue. You may experience slow data speeds in this area due to the amount of persons connected to the hotspot. -TR
# --
# Conversation 60:
#   Author: 136460
#   Inbound: True
#   Created At: Thu Nov 30 15:09:18 +0000 2017
#   Text: @sprintcare -im sure if u had to take care of ur customer svc issues PUBLICLY my family would hv had a much diff experience. Maybe u would hv discovered how to be helpful #sprintDOESNOTcare #shadysprint #sprintfail #leavingsprint
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:20:33 +0000 2017
#   Text: @136460 Hello Kelsie, we hate to hear you having issues with our customer service. But how can I help you today?
# --
#   Author: 136460
#   Inbound: True
#   Created At: Thu Nov 30 15:27:13 +0000 2017
#   Text: @sprintcare Doubt it! Tired of wasting my time. FOUR do u hear me FOUR cust svc agents &amp; NO ONE is "AUTHORIZED" 2do anything! Connect me w upper mgmt who can! Tired of being shuffled around
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:28:40 +0000 2017
#   Text: @136460 I understand the frustration but can you tell me the issue you having today?
# --
#   Author: 136460
#   Inbound: True
#   Created At: Thu Nov 30 15:42:07 +0000 2017
#   Text: @sprintcare Expect same promo offered 2new customers. $350 off iphone 8plus. Would buy (2) Iphone 8plus 256gb. Shady 2deny it to 16yr customer when willing 2abide by lease agreement. If we WERE NOT sprint customers we would hv gotten the deal few days ago when I originally called cust care
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:54:03 +0000 2017
#   Text: @136460 I understand and appreciate your loyalty for 16 years, and I know some offers are targeted for new customers we do have deals on the iphone x and 8s but its only for the 64gb I can check to seeing about upgrading to that phone and see if we can save you the $350?
# --
#   Author: 136460
#   Inbound: True
#   Created At: Thu Nov 30 16:02:39 +0000 2017
#   Text: @sprintcare Appreciate the effort. Yes, plz see if consideration will be extended to us.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 16:05:49 +0000 2017
#   Text: @136460 Ok I'm going to check the account and see the deals we have for you.
# --
#   Author: 136460
#   Inbound: True
#   Created At: Thu Nov 30 16:09:19 +0000 2017
#   Text: @sprintcare Not asking for anything more than what you are offering new customers - who u hv no relationship with. Consideration is all im asking for.
# --
# Conversation 61:
#   Author: 136461
#   Inbound: True
#   Created At: Thu Nov 30 15:45:04 +0000 2017
#   Text: @sprintcare @115714 A tower has been down near my 🏠 for 2 wks making my📱inoperable at 🏠. Sprint doesn’t care but expects me to pay my bill 🤔
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:52:18 +0000 2017
#   Text: @136461 DM us to take a closer look and get this resolved for you! -Maria Q
# --
# Conversation 62:
#   Author: 136462
#   Inbound: True
#   Created At: Thu Nov 30 15:32:49 +0000 2017
#   Text: @sprintcare Hello, I have called both my local Sprint store and the general customer service several times about a phone that I ordered last week, I have recieved only received two replies, telling me to call today. Today no one picked up. Please help me out.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:39:33 +0000 2017
#   Text: @136462 Good morning. Thank you for reaching out to us. We would be delighted to help. Would you please tell us more on what's going on with the phone you ordered so we can be more equipped to help? Please send us a DM. Thank you. Ange L
# --
# Conversation 63:
#   Author: 136463
#   Inbound: True
#   Created At: Thu Nov 30 15:04:06 +0000 2017
#   Text: I ain’t getting shit with this sorry ass @sprintcare @115714 3G https://t.co/kZtjTH8Qvy
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:39:16 +0000 2017
#   Text: @136463 Let's check on that services for you. Please send us a DM in order to further assist. - EG https://t.co/rMApsV8PQY
# --
# Conversation 64:
#   Author: 136468
#   Inbound: True
#   Created At: Thu Nov 30 14:06:33 +0000 2017
#   Text: Me after getting off the chat with @sprintcare @115714 they've truly tested my #loyalty for the 1st time... and now idk anymore
# #loyaltyiseverything
# #betrayal #time4change #relations https://t.co/edYunxddnJ
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:24:47 +0000 2017
#   Text: @136468 Hey! What seems to be the issue? Send me a DM. -ND
# --
# Conversation 65:
#   Author: 136469
#   Inbound: True
#   Created At: Thu Nov 30 14:58:17 +0000 2017
#   Text: @sprintcare for the past hour, I've been unable to log into my online account
#
# ERROR MESSAGE: ERR_CONNECTION_RESET
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:24:10 +0000 2017
#   Text: @136469 Thanks for bringing this to our attention. Try clearing the history on your browser and try again. - JM
# --
# Conversation 66:
#   Author: 136470
#   Inbound: True
#   Created At: Thu Nov 30 14:19:44 +0000 2017
#   Text: Shout out to @sprintcare Michelle in OK City for awesome customer service this morning. Once again #Sprint great customer service is #1 reason I’ve been w/ them for 15 years.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 15:18:07 +0000 2017
#   Text: @136470 Awesome! Thank you for the positive feedback and for being a loyal customer. You are one of the reasons why we are here. Thank you for reaching out to us. Thank you for choosing Sprint. -CO
# --
# Conversation 67:
#   Author: 138017
#   Inbound: True
#   Created At: Thu Nov 30 16:52:30 +0000 2017
#   Text: Had a loyalty credit for years with Sprint....I guess i am no longer loyal because they took it away?!?  Feels bad!  @sprintcare
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 17:21:20 +0000 2017
#   Text: @138017 If you upgraded your line or changed plans, the discount may have been removed. If you upgrade, you need to revalidate eligibility. Please visit https://t.co/PCU7wGFAoR - JM
# --
#   Author: 138017
#   Inbound: True
#   Created At: Thu Nov 30 17:30:57 +0000 2017
#   Text: @sprintcare Maybe you should revisit the definition of what it means to be loyal.   It is not something that comes and goes with plans or upgrades....
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 17:43:31 +0000 2017
#   Text: @138017 The previous response was made in an attempt to be informative and to shed some light into what may have happened to the discount you used to receive. It has nothing to do with the loyalty definition. - JM
# --
#   Author: 138017
#   Inbound: True
#   Created At: Thu Nov 30 18:38:19 +0000 2017
#   Text: @sprintcare Appreciate that JM,  unfortunately, this 18 year LOYAL customer will be looking for another service provider.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 18:42:44 +0000 2017
#   Text: @138017 Thanks for replying back. You are willing to leave without even finding out what happened? - JM
# --
# Conversation 68:
#   Author: 138019
#   Inbound: True
#   Created At: Thu Nov 30 17:08:42 +0000 2017
#   Text: Hey @sprintcare how can I stop all the robo calls ? 5-7 a day!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Thu Nov 30 17:14:06 +0000 2017
# ...
# --
# Conversation 889:
#   Author: 382106
#   Inbound: True
#   Created At: Mon Oct 23 23:00:48 +0000 2017
#   Text: @sprintcare The signal quality in the 48185/48150 area of Michigan is poor at best. 1 Bar isn’t quality. This must change #PoorCoverage #Bad
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 01:34:05 +0000 2017
#   Text: @382106 Hey David. Thank you so much for reaching out on this issue. Please send us a DM so we can further assist you. -SB
# --
# Conversation 890:
#   Author: 382165
#   Inbound: True
#   Created At: Sat Oct 14 04:49:52 +0000 2017
#   Text: Hey @sprintcare since @VerizonSupport refuses to admit fault with this issue, you just won yourselves a customer.  Congrats!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 04:52:40 +0000 2017
#   Text: @382165 Yayyy :) We'll be more than happy to have you join our Sprint family. :) -KA
# --
#   Author: 382165
#   Inbound: True
#   Created At: Sat Oct 14 05:02:40 +0000 2017
#   Text: @sprintcare Thank you, kindly DM me when you have a chance.
# --
# Conversation 891:
#   Author: 382791
#   Inbound: True
#   Created At: Tue Oct 24 02:44:51 +0000 2017
#   Text: @sprintcare https://t.co/dXLEIYEGYu
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 02:50:25 +0000 2017
#   Text: @382791 Hey! What makes you feel this way about us? We're here to assist in any way we can. -KA
# --
#   Author: 382791
#   Inbound: True
#   Created At: Tue Oct 24 02:56:14 +0000 2017
#   Text: @sprintcare There is no way you're within 1% of anyone. Sprint was bad 10 years ago when I had it &amp; was hoping it was better. Nope.Not even a little bit
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 02:59:27 +0000 2017
#   Text: @382791 We'd like to look into this for you. Please follow us so that we can DM you and further assist. -KA
# --
#   Author: 382791
#   Inbound: True
#   Created At: Tue Oct 24 03:01:17 +0000 2017
#   Text: @sprintcare Really ?  What could you possibly do?  You have to improve your network in Southern NJ
# --
# Conversation 892:
#   Author: 383247
#   Inbound: True
#   Created At: Tue Oct 24 03:19:21 +0000 2017
#   Text: @sprintcare you customer service needs improvement and keeping longtime customers should be a priority. I’m very disappointed in the service
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 03:44:41 +0000 2017
#   Text: @383247 Hi Gray. We are sorry you encountered poor customer service. How may we assist you? -CA
# --
#   Author: 383247
#   Inbound: True
#   Created At: Tue Oct 24 03:45:50 +0000 2017
#   Text: @sprintcare To start, Address my issue and provide the services I pay for.
# --
# Conversation 893:
#   Author: 384929
#   Inbound: True
#   Created At: Sat Oct 14 13:17:51 +0000 2017
#   Text: @sprintcare How do i get the dead for the discounted iPhone 8 with a trade in? Do I have to go into the store?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 13:36:21 +0000 2017
#   Text: @384929 getting in contact with our Sales Department over the phone dialing 800-777-4681 or going to a Sprint Store. (2/2) -CB
# --
# Conversation 894:
#   Author: 184089
#   Inbound: True
#   Created At: Sat Oct 14 15:14:04 +0000 2017
#   Text: @sprintcare @115714 #worst #coverage in the smallest state. #ri #RhodeIsland   👎🏻👎🏻👎🏻👎🏻
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 15:16:12 +0000 2017
#   Text: @184089 Hey there! Please send us a DM so we can further assist. -MM
# --
# Conversation 895:
#   Author: 386501
#   Inbound: True
#   Created At: Tue Oct 24 11:48:06 +0000 2017
#   Text: @115714 @sprintcare
# Sprint employees set me up to be scammed $400.00
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 11:51:54 +0000 2017
#   Text: @386501 Hi there. This is very concerning. Please send us a DM for further assistance. -EG
# --
#   Author: 386501
#   Inbound: True
#   Created At: Tue Oct 24 15:06:07 +0000 2017
#   Text: @sprintcare I trusted the company because the number was given to me by an inefficient Sprint employee!!!
# --
# Conversation 896:
#   Author: 386538
#   Inbound: True
#   Created At: Sat Oct 14 16:30:31 +0000 2017
#   Text: @sprintcare Sprint has the worst coverage!! Canceling 3 lines as we speak I suggest you do the same!!!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 16:33:57 +0000 2017
#   Text: @386538 Oh no! We'd hate to lose you as a sprint customer. Is there anything we can do to assist you? -CD
# --
#   Author: 386538
#   Inbound: True
#   Created At: Sat Oct 14 16:40:42 +0000 2017
#   Text: @sprintcare Turned to Twitter because phone rep refused to help me..wtf!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 16:45:12 +0000 2017
#   Text: @386538 Wow, I can definitely understand the frustration! I'd love to help you sort this out, can you send us a DM so we can further assist you? -CD
# --
# Conversation 897:
#   Author: 386574
#   Inbound: True
#   Created At: Sun Oct 15 14:43:49 +0000 2017
#   Text: @sprintcare Rep answered, found out I wanted to cancel a line. Put me on hold for FORTY MINUTES and hung up. I am BEYOND upset right now.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 14:50:33 +0000 2017
#   Text: @386574 callback number in the direct message and I will call you.
# --
# Conversation 898:
#   Author: 191555
#   Inbound: True
#   Created At: Tue Oct 24 07:25:32 +0000 2017
#   Text: @115714 @sprintcare y am I being charge $12 for total tech expert when it's supposed to be included with TEP+ ? I never asked for it ! https://t.co/h3H8OW0WLx
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 12:15:38 +0000 2017
#   Text: @191555 Good morning, If you require assistance.   Please DM us or provide the best time to contact you.
# --
# Conversation 899:
#   Author: 387084
#   Inbound: True
#   Created At: Tue Oct 24 12:25:05 +0000 2017
#   Text: Look @sprintcare if you all can’t fix your towers so I don’t drop calls 6+ times on a major hwy I’m done. Approx $500/month for spotty svc?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 12:34:05 +0000 2017
#   Text: @387084 We would like to refresh your device. Please send us a Direct Message, so that we can further assist you. - LS
# --
# Conversation 900:
#   Author: 387921
#   Inbound: True
#   Created At: Sat Oct 14 18:39:19 +0000 2017
#   Text: BUT @115714 @sprintcare @116447 will not agree to honor terms!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 18:45:47 +0000 2017
#   Text: @387921 A member of Team @116447 will reach out to you shortly.
# --
#   Author: 387921
#   Inbound: True
#   Created At: Sat Oct 14 19:04:26 +0000 2017
#   Text: @sprintcare @116447 I received a message to call 866-860-8040, but that is not a Sprint line. Please either call me again or send me the correct phone number.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 19:06:01 +0000 2017
#   Text: @387921 Team @116447 will be reaching out shortly.
# --
# Conversation 901:
#   Author: 139144
#   Inbound: True
#   Created At: Tue Oct 24 15:06:19 +0000 2017
#   Text: @115714 @sprintcare reach their 5gb they go to 2gb something must change
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 15:18:15 +0000 2017
#   Text: @139144 40 gig cause most of the time people will use more then others. But what you can do to split it is go on to the
# --
# Conversation 902:
#   Author: 121555
#   Inbound: True
#   Created At: Sat Oct 14 19:55:31 +0000 2017
#   Text: @116447 @sprintcare I tweeted out to speak with a regulatory rep and was told u would contact me and u haven’t poor costumer service!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 20:03:20 +0000 2017
#   Text: @121555 We apologize for any inconvenience. We will have an analyst reach out shortly. Team @116447
# --
#   Author: 121555
#   Inbound: True
#   Created At: Sat Oct 14 20:10:14 +0000 2017
#   Text: @sprintcare @116447 Ok
# --
# Conversation 903:
#   Author: 389079
#   Inbound: True
#   Created At: Sat Oct 14 20:40:50 +0000 2017
#   Text: @sprintcare Don't need them since switching from @115911 online deal sent me sims. Not a good start for a new customer.
# --
# Conversation 904:
#   Author: 389396
#   Inbound: True
#   Created At: Tue Oct 24 13:09:33 +0000 2017
#   Text: @sprintcare hi I'm in Puerto Rico and I just got billed for Sept. Ads say that customers get 2 months credit. Which is it? Thanks
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 13:20:42 +0000 2017
#   Text: @389396 Thanks for reaching out to us. Yes that is true. Please send us a Direct Message, so that we can further assist you. -MJ
# --
#   Author: 120574
#   Inbound: True
#   Created At: Tue Oct 24 13:27:45 +0000 2017
#   Text: @sprintcare @389396 Don't reach out. They are horrible. Switch to another company. You will be much happier.
#
# #TrustMe
# #ThankMeLater
# --
# Conversation 905:
#   Author: 389604
#   Inbound: True
#   Created At: Tue Oct 24 13:32:23 +0000 2017
#   Text: @sprintcare thank you for my extension 🤘🏾you guys rock
# sometimes....lol
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 13:40:50 +0000 2017
#   Text: @389604 Always a pleasure hearing from you! Feel free to reach out for any future assistance. =) -NL
# --
# Conversation 906:
#   Author: 359513
#   Inbound: True
#   Created At: Sat Oct 14 22:13:32 +0000 2017
#   Text: @sprintcare Unlock my wifes phone https://t.co/0qKzB5Gr5y
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sat Oct 14 22:17:51 +0000 2017
#   Text: @359513 If it was leased did she pay off the lease balance and the additional balance to own the phone?
# --
#   Author: 359513
#   Inbound: True
#   Created At: Sun Oct 15 02:06:42 +0000 2017
#   Text: @sprintcare And yes she is on auto pay for her monthly payment
# --
# Conversation 907:
#   Author: 390252
#   Inbound: True
#   Created At: Tue Oct 24 14:22:30 +0000 2017
#   Text: @sprintcare service outage in Syracuse area - neither my husband nor my phone working
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 14:24:31 +0000 2017
#   Text: @390252 Hi Kelly! Can you DM us so that we can investigate further? -CB
# --
# Conversation 908:
#   Author: 390977
#   Inbound: True
#   Created At: Tue Oct 24 14:45:59 +0000 2017
#   Text: @sprintcare terrible customer service and fucked through the mail refund policy
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 15:02:06 +0000 2017
#   Text: @390977 So sorry to hear that. Please send us a Direct Message, so that we can further assist you. -DJ
# --
# Conversation 909:
#   Author: 391340
#   Inbound: True
#   Created At: Tue Oct 24 17:06:59 +0000 2017
#   Text: Yo @sprintcare, what are u guys smokin? No way I owe u $207.36. I quit u a month ago! @115714
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 17:16:09 +0000 2017
#   Text: @391340 I'm sorry for the trouble, let's get this fixed for you. Shoot us a DM. -DJ
# --
#   Author: 391340
#   Inbound: True
#   Created At: Tue Oct 24 17:25:26 +0000 2017
#   Text: @sprintcare You know me...look in our chat history. 612.310.2319. #6127227220. Figure it out and get back to me. So done with Sprint!
# --
# Conversation 910:
#   Author: 391573
#   Inbound: True
#   Created At: Sun Oct 15 17:45:26 +0000 2017
#   Text: @sprintcare how many customer service/sales reps does it take to upgrade a phone? 5 reps, 90 minutes, no phone upgrade. https://t.co/utk6K77TAG
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 17:59:39 +0000 2017
#   Text: @391573 I was unable to see your previous message. Can  you resend it? YP
# --
#   Author: 391573
#   Inbound: True
#   Created At: Sun Oct 15 18:12:43 +0000 2017
#   Text: @sprintcare I sent a direct message.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 18:14:37 +0000 2017
#   Text: @391573 I would need to take a look at your account. Can you click on the secure link above? YP
# --
#   Author: 391573
#   Inbound: True
#   Created At: Sun Oct 15 18:32:23 +0000 2017
#   Text: @sprintcare You guys really know how to win a girl over....now I'm waiting for "an agent to join" the conversation. https://t.co/Pxg5qZ6yUl
# --
# Conversation 911:
#   Author: 391642
#   Inbound: True
#   Created At: Tue Oct 24 17:37:18 +0000 2017
#   Text: @sprintcare Who do I contact to make a compliant against the customer service representatives?
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 17:43:07 +0000 2017
#   Text: @391642 We can definitely provide feedback! Please DM us -Maria Q
# --
# Conversation 912:
#   Author: 391974
#   Inbound: True
#   Created At: Sun Oct 15 16:11:47 +0000 2017
#   Text: Sure would be nice to get some competent customer service from @sprintcare
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 16:59:16 +0000 2017
#   Text: @391974 Hey! Hope you’re doing well today. How can I help? -NS
# --
#   Author: 391974
#   Inbound: True
#   Created At: Sun Oct 15 17:57:55 +0000 2017
#   Text: @sprintcare All i need is an itemized bill
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 18:06:05 +0000 2017
#   Text: @391974 We would be happy to assist you with this. Send us a DM -NS https://t.co/rMApsV8PQY
# --
# Conversation 913:
#   Author: 392238
#   Inbound: True
#   Created At: Tue Oct 24 16:01:14 +0000 2017
#   Text: Woke up pissed because of @sprintcare!
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:03:00 +0000 2017
#   Text: @392238 This is concerning to hear! What's going on? - AM
# --
#   Author: 392238
#   Inbound: True
#   Created At: Tue Oct 24 16:07:24 +0000 2017
#   Text: @sprintcare Your team randomly cancelled my husband's line.  Now I wait to see what happens with my bill with this mistake.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:10:58 +0000 2017
#   Text: @392238 This is concerning! Please send us a DM so that we can assist. - AM
# --
#   Author: 392238
#   Inbound: True
#   Created At: Tue Oct 24 16:12:21 +0000 2017
#   Text: @sprintcare Yeah, super concerning as he needs his phone for work.  Your reps have bad listening skills.  😠
# --
# Conversation 914:
#   Author: 392241
#   Inbound: True
#   Created At: Tue Oct 24 15:16:32 +0000 2017
#   Text: Got a brand new phone from @115725 yesterday! Now I can't send or receive text messages. Should have stayed with @sprintcare .
# --
# Conversation 915:
#   Author: 392388
#   Inbound: True
#   Created At: Sun Oct 15 17:31:23 +0000 2017
#   Text: @sprintcare WTF is going on in Minneapolis? I assume my bill will be decreased this month.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Sun Oct 15 18:18:38 +0000 2017
#   Text: @392388 How long have you been having this issue. -AH
# --
# Conversation 916:
#   Author: 392581
#   Inbound: True
#   Created At: Tue Oct 24 16:12:24 +0000 2017
#   Text: I’ve never had such a long damn process to return a leased phone. @sprintcare  Please help.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:15:15 +0000 2017
#   Text: @392581 Or we can send out a return kit and you can mail the phone back to us. -FR
# --
#   Author: 392581
#   Inbound: True
#   Created At: Tue Oct 24 16:16:22 +0000 2017
#   Text: @sprintcare I’ll go to a store. A return kit was supposed to arrive last week.
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:21:02 +0000 2017
#   Text: @392581 I am sorry but the best way is to go the store because you get a receipt that you can hold on to for proof of return. -FR
# --
#   Author: 392581
#   Inbound: True
#   Created At: Tue Oct 24 16:26:32 +0000 2017
#   Text: @sprintcare Two months of my time has been wasted on this and my card was charged $700 because I never received a return package smh
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:29:36 +0000 2017
#   Text: @392581 We're so sorry for that, Shandy. Can you DM us, we can take a look at an return kit status? We definitely want to expedite this. -CDE
# --
# Conversation 917:
#   Author: 392913
#   Inbound: True
#   Created At: Tue Oct 24 16:19:52 +0000 2017
#   Text: @sprintcare after over an hour keeping my account. $10 charge to mail the phone? Congrats for keeping an UNHAPPY cust
# --
#   Author: sprintcare
#   Inbound: False
#   Created At: Tue Oct 24 16:35:15 +0000 2017
#   Text: @392913 Oh no! Allow us to turn this around! Please DM us -Maria Q
# --

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The analysis successfully identified tweets that initiated conversations by filtering for entries where `in_response_to_tweet_id` was null.
# *   The first 20 conversation threads were traced by matching `tweet_id` with `in_response_to_tweet_id` to link replies to their preceding tweets.
# *   The tweets within the first 20 conversations were structured into a list of dictionaries, each containing the `tweet_id`, `author_id`, `inbound` status, `created_at` timestamp, and the `text` of the tweet.
# *   The content of the first 20 structured conversations was displayed, showing the author, inbound status, creation timestamp, and text for each tweet in the thread.

# %% [markdown]
# ## Convert to JSON and Save
#
# ### Subtask:
# Convert the structured conversations into a JSON format and save to a file.

# %% [markdown]
# **Reasoning**:
# Use the `json` library to convert the `structured_conversations` list into a JSON formatted string and write it to a file.

# %%
import json
import numpy as np
from datetime import datetime
import pytz

# Get current time in Indian Standard Time (IST)
ist = pytz.timezone('Asia/Kolkata')
current_time_ist = datetime.now(ist)

# Generate filename with current date and time (IST) in requested format
formatted_time = current_time_ist.strftime('%Y%m%d_%H%M%S')
output_filename = f'sprintcare_{formatted_time}.json'

# Custom encoder to handle NumPy types, including booleans
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.bool_):
            return bool(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

with open(output_filename, 'w') as f:
    json.dump(structured_conversations, f, indent=4, cls=NpEncoder)

print(f"Structured conversations saved to '{output_filename}'")
# Out:
# Structured conversations saved to 'sprintcare_20250916_104348.json'

# %%
# !pip install pytz
# Out:
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (2025.2)
